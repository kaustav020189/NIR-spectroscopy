# %%
import numpy as np # linear algebra
import seaborn as sns
sns.set(style="whitegrid")
import warnings
warnings.filterwarnings('ignore')
import util

# %% [markdown]
# <h2 style="color: #dddda1">Data Split 1 (80 / 20 - Train / Test)</h2>

# %%
file_name = ['2022_07_13.csv', '2022_06_22.csv', '2022_06_24.csv', '2022_06_29.csv']
X, y, wl = util.data_initialization(filename=file_name[0], sep=";", drop_columns=['Timestamp', 'TS_sim'], index_column='Timestamp', y_data_column='TS_sim')

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)
util.plot(wl, X_train, title='Training Data Raw Spectrum', xlabel='Wavelength', ylabel='Absorbance')
